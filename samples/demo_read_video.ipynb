# %% [markdown]
# # Mask R-CNN Demo
#
# A quick intro to using the pre-trained model to detect and segment objects.

# %%
import os
import sys
import random
import math
import numpy as np
import skimage.io
import matplotlib
import matplotlib.pyplot as plt
import cv2

# Root directory of the project
ROOT_DIR = os.path.abspath("../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
# Import COCO config
sys.path.append(os.path.join(ROOT_DIR, "samples/coco/"))  # To find local version
import coco

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)

# Directory of images to run detection on
IMAGE_DIR = os.path.join(ROOT_DIR, "images")
# Out:
# d:\program\anaconda\envs\maskrcnn\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Configurations
#
# We'll be using a model trained on the MS-COCO dataset. The configurations of this model are in the ```CocoConfig``` class in ```coco.py```.
#
# For inferencing, modify the configurations a bit to fit the task. To do so, sub-class the ```CocoConfig``` class and override the attributes you need to change.

# %%
class InferenceConfig(coco.CocoConfig):
    # Set batch size to 1 since we'll be running inference on
    # one image at a time. Batch size = GPU_COUNT * IMAGES_PER_GPU
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Create Model and Load Trained Weights

# %%
# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=config)

# Load weights trained on MS-COCO
model.load_weights(COCO_MODEL_PATH, by_name=True)

# %% [markdown]
# ## Class Names
#
# The model classifies objects and returns class IDs, which are integer value that identify each class. Some datasets assign integer values to their classes and some don't. For example, in the MS-COCO dataset, the 'person' class is 1 and 'teddy bear' is 88. The IDs are often sequential, but not always. The COCO dataset, for example, has classes associated with class IDs 70 and 72, but not 71.
#
# To improve consistency, and to support training on data from multiple sources at the same time, our ```Dataset``` class assigns it's own sequential integer IDs to each class. For example, if you load the COCO dataset using our ```Dataset``` class, the 'person' class would get class ID = 1 (just like COCO) and the 'teddy bear' class is 78 (different from COCO). Keep that in mind when mapping class IDs to class names.
#
# To get the list of class names, you'd load the dataset and then use the ```class_names``` property like this.
# ```
# # Load COCO dataset
# dataset = coco.CocoDataset()
# dataset.load_coco(COCO_DIR, "train")
# dataset.prepare()
#
# # Print class names
# print(dataset.class_names)
# ```
#
# We don't want to require you to download the COCO dataset just to run this demo, so we're including the list of class names below. The index of the class name in the list represent its ID (first class is 0, second is 1, third is 2, ...etc.)

# %%
# COCO Class names
# Index of the class in the list is its ID. For example, to get ID of
# the teddy bear class, use: class_names.index('teddy bear')
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']

# %% [markdown]
# ## Run Object Detection

# %%
# Load a random image from the images folder
file_names = next(os.walk(IMAGE_DIR))[2]
#image = skimage.io.imread(os.path.join(IMAGE_DIR, random.choice(file_names)))

filename=os.path.join(IMAGE_DIR,'dog.jpg')
image = skimage.io.imread(filename)

# Run detection
results = model.detect([image], verbose=1)

# Visualize results
r = results[0]
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            class_names, r['scores'])
# Out:
# Processing 1 images
# image                    shape: (1487, 2035, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 2035.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32

# %%
mkdir videos
# Out:
# 子目录或文件 videos 已经存在。

# %%
ls ./videos
# Out:
# 无效开关 - "videos"。

# %%
import cv2
import numpy as np

def random_colors(N):
    np.random.seed(1)
    colors=[tuple(255 * np.random.rand(3)) for _ in range(N)]
    return colors

def apply_mask(image,mask,color,alpha=0.5):
    for n, c in enumerate(color):
        image[:, :, n] = np.where(
            mask == 1,
            image[:, :, n] * (1 - alpha) + alpha * c,
            image[:, :, n]
        )
    return image


def display_instances(image, boxes, masks, ids, names, scores):
    """
        take the image and results and apply the mask, box, and Label
    """
    n_instances = boxes.shape[0]
    colors = random_colors(n_instances)

    if not n_instances:
        print('NO INSTANCES TO DISPLAY')
    else:
        assert boxes.shape[0] == masks.shape[-1] == ids.shape[0]

    for i, color in enumerate(colors):
        if not np.any(boxes[i]):
            continue

        y1, x1, y2, x2 = boxes[i]
        label = names[ids[i]]
        score = scores[i] if scores is not None else None
        caption = '{} {:.2f}'.format(label, score) if score else label
        mask = masks[:, :, i]

        image = apply_mask(image, mask, color)
        image = cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        image = cv2.putText(
            image, caption, (x1, y1), cv2.FONT_HERSHEY_COMPLEX, 0.7, color, 2
        )

    return image

if __name__ == '__main__':
    """
        test everything
    """
    import os
    import sys
    from mrcnn import utils
    import mrcnn.model as modellib
    from mrcnn import visualize
    import coco
    
    # We use a K80 GPU with 24GB memory, which can fit 3 images.
    batch_size = 3

    #ROOT_DIR = os.getcwd()
    ROOT_DIR =os.path.abspath("../")
    MODEL_DIR = os.path.join(ROOT_DIR, "logs")
    VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
    VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "save2")
    COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
    if not os.path.exists(COCO_MODEL_PATH):
        utils.download_trained_weights(COCO_MODEL_PATH)

    class InferenceConfig(coco.CocoConfig):
        GPU_COUNT = 1
        IMAGES_PER_GPU = batch_size

    config = InferenceConfig()
    config.display()

    model = modellib.MaskRCNN(
        mode="inference", model_dir=MODEL_DIR, config=config
    )
    model.load_weights(COCO_MODEL_PATH, by_name=True)
    class_names = [
        'BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
        'bus', 'train', 'truck', 'boat', 'traffic light',
        'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
        'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
        'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
        'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
        'kite', 'baseball bat', 'baseball glove', 'skateboard',
        'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
        'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
        'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
        'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
        'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
        'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
        'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
        'teddy bear', 'hair drier', 'toothbrush'
    ]

    capture = cv2.VideoCapture(os.path.join(VIDEO_DIR, 'mydesk.mp4'))
    try:
        if not os.path.exists(VIDEO_SAVE_DIR):
            os.makedirs(VIDEO_SAVE_DIR)
    except OSError:
        print ('Error: Creating directory of data')
    frames = []
    frame_count = 0
    # these 2 lines can be removed if you dont have a 1080p camera.
    capture.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)
    capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)

    while True:
        ret, frame = capture.read()
        # Bail out when the video file ends
        if not ret:
            break
        
        # Save each frame of the video to a list
        frame_count += 1
        frames.append(frame)
        print('frame_count :{0}'.format(frame_count))
        if len(frames) == batch_size:
            results = model.detect(frames, verbose=0)
            print('Predicted')
            for i, item in enumerate(zip(frames, results)):
                frame = item[0]
                r = item[1]
                frame = display_instances(
                    frame, r['rois'], r['masks'], r['class_ids'], class_names, r['scores']
                )
                name = '{0}.jpg'.format(frame_count + i - batch_size)
                name = os.path.join(VIDEO_SAVE_DIR, name)
                cv2.imwrite(name, frame)
                print('writing to file:{0}'.format(name))
            # Clear the frames array to start the next batch
            frames = []

    capture.release()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     3
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                93
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           coco
# NUM_CLASSES                    81
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001
#
#
# frame_count :1
# frame_count :2
# frame_count :3
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\0.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\1.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\2.jpg
# frame_count :4
# frame_count :5
# frame_count :6
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\3.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\4.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\5.jpg
# frame_count :7
# frame_count :8
# frame_count :9
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\6.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\7.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\8.jpg
# frame_count :10
# frame_count :11
# frame_count :12
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\9.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\10.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\11.jpg
# frame_count :13
# frame_count :14
# frame_count :15
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\12.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\13.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\14.jpg
# frame_count :16
# frame_count :17
# frame_count :18
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\15.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\16.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\17.jpg
# frame_count :19
# frame_count :20
# frame_count :21
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\18.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\19.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\20.jpg
# frame_count :22
# frame_count :23
# frame_count :24
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\21.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\22.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\23.jpg
# frame_count :25
# frame_count :26
# frame_count :27
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\24.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\25.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\26.jpg
# frame_count :28
# frame_count :29
# frame_count :30
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\27.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\28.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\29.jpg
# frame_count :31
# frame_count :32
# frame_count :33
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\30.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\31.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\32.jpg
# frame_count :34
# frame_count :35
# frame_count :36
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\33.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\34.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\35.jpg
# frame_count :37
# frame_count :38
# frame_count :39
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\36.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\37.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\38.jpg
# frame_count :40
# frame_count :41
# frame_count :42
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\39.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\40.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\41.jpg
# frame_count :43
# frame_count :44
# frame_count :45
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\42.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\43.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\44.jpg
# frame_count :46
# frame_count :47
# frame_count :48
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\45.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\46.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\47.jpg
# frame_count :49
# frame_count :50
# frame_count :51
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\48.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\49.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\50.jpg
# frame_count :52
# frame_count :53
# frame_count :54
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\51.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\52.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\53.jpg
# frame_count :55
# frame_count :56
# frame_count :57
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\54.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\55.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\56.jpg
# frame_count :58
# frame_count :59
# frame_count :60
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\57.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\58.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\59.jpg
# frame_count :61
# frame_count :62
# frame_count :63
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\60.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\61.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\62.jpg
# frame_count :64
# frame_count :65
# frame_count :66
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\63.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\64.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\65.jpg
# frame_count :67
# frame_count :68
# frame_count :69
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\66.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\67.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\68.jpg
# frame_count :70
# frame_count :71
# frame_count :72
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\69.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\70.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\71.jpg
# frame_count :73
# frame_count :74
# frame_count :75
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\72.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\73.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\74.jpg
# frame_count :76
# frame_count :77
# frame_count :78
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\75.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\76.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\77.jpg
# frame_count :79
# frame_count :80
# frame_count :81
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\78.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\79.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\80.jpg
# frame_count :82
# frame_count :83
# frame_count :84
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\81.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\82.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\83.jpg
# frame_count :85
# frame_count :86
# frame_count :87
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\84.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\85.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\86.jpg
# frame_count :88
# frame_count :89
# frame_count :90
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\87.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\88.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\89.jpg
# frame_count :91
# frame_count :92
# frame_count :93
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\90.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\91.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\92.jpg
# frame_count :94
# frame_count :95
# frame_count :96
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\93.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\94.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\95.jpg
# frame_count :97
# frame_count :98
# frame_count :99
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\96.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\97.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\98.jpg
# frame_count :100
# frame_count :101
# frame_count :102
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\99.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\100.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\101.jpg
# frame_count :103
# frame_count :104
# frame_count :105
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\102.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\103.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\104.jpg
# frame_count :106
# frame_count :107
# frame_count :108
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\105.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\106.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\107.jpg
# frame_count :109
# frame_count :110
# frame_count :111
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\108.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\109.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\110.jpg
# frame_count :112
# frame_count :113
# frame_count :114
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\111.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\112.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\113.jpg
# frame_count :115
# frame_count :116
# frame_count :117
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\114.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\115.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\116.jpg
# frame_count :118
# frame_count :119
# frame_count :120
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\117.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\118.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\119.jpg
# frame_count :121
# frame_count :122
# frame_count :123
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\120.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\121.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\122.jpg
# frame_count :124
# frame_count :125
# frame_count :126
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\123.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\124.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\125.jpg
# frame_count :127
# frame_count :128
# frame_count :129
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\126.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\127.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\128.jpg
# frame_count :130
# frame_count :131
# frame_count :132
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\129.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\130.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\131.jpg
# frame_count :133
# frame_count :134
# frame_count :135
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\132.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\133.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\134.jpg
# frame_count :136
# frame_count :137
# frame_count :138
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\135.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\136.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\137.jpg
# frame_count :139
# frame_count :140
# frame_count :141
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\138.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\139.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\140.jpg
# frame_count :142
# frame_count :143
# frame_count :144
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\141.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\142.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\143.jpg
# frame_count :145
# frame_count :146
# frame_count :147
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\144.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\145.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\146.jpg
# frame_count :148
# frame_count :149
# frame_count :150
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\147.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\148.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\149.jpg
# frame_count :151
# frame_count :152
# frame_count :153
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\150.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\151.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\152.jpg
# frame_count :154
# frame_count :155
# frame_count :156
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\153.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\154.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\155.jpg
# frame_count :157
# frame_count :158
# frame_count :159
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\156.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\157.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\158.jpg
# frame_count :160
# frame_count :161
# frame_count :162
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\159.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\160.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\161.jpg
# frame_count :163
# frame_count :164
# frame_count :165
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\162.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\163.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\164.jpg
# frame_count :166
# frame_count :167
# frame_count :168
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\165.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\166.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\167.jpg
# frame_count :169
# frame_count :170
# frame_count :171
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\168.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\169.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\170.jpg
# frame_count :172
# frame_count :173
# frame_count :174
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\171.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\172.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\173.jpg
# frame_count :175
# frame_count :176
# frame_count :177
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\174.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\175.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\176.jpg
# frame_count :178
# frame_count :179
# frame_count :180
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\177.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\178.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\179.jpg
# frame_count :181
# frame_count :182
# frame_count :183
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\180.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\181.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\182.jpg
# frame_count :184
# frame_count :185
# frame_count :186
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\183.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\184.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\185.jpg
# frame_count :187
# frame_count :188
# frame_count :189
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\186.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\187.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\188.jpg
# frame_count :190
# frame_count :191
# frame_count :192
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\189.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\190.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\191.jpg
# frame_count :193
# frame_count :194
# frame_count :195
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\192.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\193.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\194.jpg
# frame_count :196
# frame_count :197
# frame_count :198
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\195.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\196.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\197.jpg
# frame_count :199
# frame_count :200
# frame_count :201
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\198.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\199.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\200.jpg
# frame_count :202
# frame_count :203
# frame_count :204
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\201.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\202.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\203.jpg
# frame_count :205
# frame_count :206
# frame_count :207
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\204.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\205.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\206.jpg
# frame_count :208
# frame_count :209
# frame_count :210
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\207.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\208.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\209.jpg
# frame_count :211
# frame_count :212
# frame_count :213
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\210.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\211.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\212.jpg
# frame_count :214
# frame_count :215
# frame_count :216
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\213.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\214.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\215.jpg
# frame_count :217
# frame_count :218
# frame_count :219
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\216.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\217.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\218.jpg
# frame_count :220
# frame_count :221
# frame_count :222
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\219.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\220.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\221.jpg
# frame_count :223
# frame_count :224
# frame_count :225
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\222.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\223.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\224.jpg
# frame_count :226
# frame_count :227
# frame_count :228
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\225.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\226.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\227.jpg
# frame_count :229
# frame_count :230
# frame_count :231
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\228.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\229.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\230.jpg
# frame_count :232
# frame_count :233
# frame_count :234
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\231.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\232.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\233.jpg
# frame_count :235
# frame_count :236
# frame_count :237
# Predicted
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\234.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\235.jpg
# writing to file:F:\jupyterNotebook\Mask_RCNN\videos\save2\236.jpg
# frame_count :238
# frame_count :239

# %%
video = cv2.VideoCapture(os.path.join(VIDEO_DIR, 'mydesk.mp4'));

# Find OpenCV version
(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')

if int(major_ver)  < 3 :
    fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}".format(fps))
else :
    fps = video.get(cv2.CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(fps))

video.release();
# Out:
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 29.609746025190997

# %%
def make_video(outvid, images=None, fps=30, size=None,
               is_color=True, format="FMP4"):
    """
    Create a video from a list of images.
 
    @param      outvid      output video
    @param      images      list of images to use in the video
    @param      fps         frame per second
    @param      size        size of each frame
    @param      is_color    color
    @param      format      see http://www.fourcc.org/codecs.php
    @return                 see http://opencv-python-tutroals.readthedocs.org/en/latest/py_tutorials/py_gui/py_video_display/py_video_display.html
 
    The function relies on http://opencv-python-tutroals.readthedocs.org/en/latest/.
    By default, the video will have the size of the first image.
    It will resize every image to this size before adding them to the video.
    """
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
    #vid.release()
    return vid

import glob
import os

# Directory of images to run detection on
ROOT_DIR =os.path.abspath("../")
VIDEO_DIR = os.path.join(ROOT_DIR, "videos")
VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "save2")
images = list(glob.iglob(os.path.join(VIDEO_SAVE_DIR, '*.*')))
# Sort the images by integer index
images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))

outvid = os.path.join(VIDEO_DIR, "mydesk_out.mp4")
make_video(outvid, images, fps=30)
print('make video success')
# Out:
# make video success
